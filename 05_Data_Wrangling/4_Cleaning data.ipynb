# %% [markdown]
# ## Cleaning data with Python.

# %%
# Import packages
import pandas as pd

# Import dataset
auto = pd.read_csv("autodata.csv")

# Display auto
auto
# Out:
#   Manufacturer        Model  Drive EngineType  Cylinders  Liters    MPG
# 0         Audi           A4    All        Gas        4.0     2.0   24.0
# 1          BMW       328 Ci   Rear        Gas        6.0     3.6  210.0
# 2      Bentley  Continental   Rear        Gas        NaN     NaN   21.0
# 3    Chevrolet       Malibu  Front        Gas        6.0     3.6   18.0
# 4         Ford      Mustang   Rear        Gas        6.0     3.7    NaN
# 5  Rolls-Royce        Ghost   Rear        Gas       12.0     6.6   12.0
# 6    Chevrolet       Malibu  Front        Gas        6.0     3.6   18.0

# %%
# Which rows have missing values?
auto.isnull()
# Out:
#    Manufacturer  Model  Drive  EngineType  Cylinders  Liters    MPG
# 0         False  False  False       False      False   False  False
# 1         False  False  False       False      False   False  False
# 2         False  False  False       False       True    True  False
# 3         False  False  False       False      False   False  False
# 4         False  False  False       False      False   False   True
# 5         False  False  False       False      False   False  False
# 6         False  False  False       False      False   False  False

# %%
# Count the colm with missing values for each feature
auto.isnull().sum()
# Out:
# Manufacturer    0
# Model           0
# Drive           0
# EngineType      0
# Cylinders       1
# Liters          1
# MPG             1
# dtype: int64

# %%
# Remove duplicates from dataset
auto.drop_duplicates(inplace=True)
auto
# Out:
#   Manufacturer        Model  Drive EngineType  Cylinders  Liters    MPG
# 0         Audi           A4    All        Gas        4.0     2.0   24.0
# 1          BMW       328 Ci   Rear        Gas        6.0     3.6  210.0
# 2      Bentley  Continental   Rear        Gas        NaN     NaN   21.0
# 3    Chevrolet       Malibu  Front        Gas        6.0     3.6   18.0
# 4         Ford      Mustang   Rear        Gas        6.0     3.7    NaN
# 5  Rolls-Royce        Ghost   Rear        Gas       12.0     6.6   12.0

# %%
# Remove rows with missing values for both Cylinders and Liters
auto.dropna(subset=['Cylinders', 'Liters'], how='all', inplace=True)
auto
# Out:
#   Manufacturer    Model  Drive EngineType  Cylinders  Liters    MPG
# 0         Audi       A4    All        Gas        4.0     2.0   24.0
# 1          BMW   328 Ci   Rear        Gas        6.0     3.6  210.0
# 3    Chevrolet   Malibu  Front        Gas        6.0     3.6   18.0
# 4         Ford  Mustang   Rear        Gas        6.0     3.7    NaN
# 5  Rolls-Royce    Ghost   Rear        Gas       12.0     6.6   12.0

# %%
# Remove features with missing values in a given row
auto.dropna(axis=1, subset=[3])
auto
# Out:
#   Manufacturer    Model  Drive EngineType  Cylinders  Liters    MPG
# 0         Audi       A4    All        Gas        4.0     2.0   24.0
# 1          BMW   328 Ci   Rear        Gas        6.0     3.6  210.0
# 3    Chevrolet   Malibu  Front        Gas        6.0     3.6   18.0
# 4         Ford  Mustang   Rear        Gas        6.0     3.7    NaN
# 5  Rolls-Royce    Ghost   Rear        Gas       12.0     6.6   12.0

# %%
auto.replace(to_replace=210.0, value=21, inplace=True)
auto
# Out:
#   Manufacturer    Model  Drive EngineType  Cylinders  Liters   MPG
# 0         Audi       A4    All        Gas        4.0     2.0  24.0
# 1          BMW   328 Ci   Rear        Gas        6.0     3.6  21.0
# 3    Chevrolet   Malibu  Front        Gas        6.0     3.6  18.0
# 4         Ford  Mustang   Rear        Gas        6.0     3.7   NaN
# 5  Rolls-Royce    Ghost   Rear        Gas       12.0     6.6  12.0

# %%
# Compute mean values of numeric features
mean = auto.mean(numeric_only=True)
auto.fillna(value=mean, inplace=True)
auto
# Out:
#   Manufacturer    Model  Drive EngineType  Cylinders  Liters    MPG
# 0         Audi       A4    All        Gas        4.0     2.0  24.00
# 1          BMW   328 Ci   Rear        Gas        6.0     3.6  21.00
# 3    Chevrolet   Malibu  Front        Gas        6.0     3.6  18.00
# 4         Ford  Mustang   Rear        Gas        6.0     3.7  18.75
# 5  Rolls-Royce    Ghost   Rear        Gas       12.0     6.6  12.00

# %% [markdown]
# ## challenge activity 5.4.2: Cleaning data using pandas.

# %% [markdown]
# ## This dataset contains information on lifestyle measures such as the amount of sunshine, pollution, and happiness levels for 44 major cities around the world.
#
# * **Drop instances with duplicate values of sunshine_hours from the dataset.**
# *
# **The code contains all imports, loads the dataset, and displays healthyClean.info().**

# %%
# Import packages and functions
import pandas as pd

# Load the dataset
healthy = pd.read_csv('healthy_example.csv')


# Remove instances with duplicate values of sunshine_hours 
healthy = healthy.drop_duplicates(subset=['sunshine_hours'])  

healthy
# Out:
#    cost_bottled_water  annual_hours_worked  sunshine_hours  \
# 0               £1.92               1434.0          1858.0
# 1               £1.48               1712.0          2636.0
# 2               £1.94               1501.0          1884.0
# 3               £1.72               1452.0          1821.0
# 4               £2.19               1380.0          1630.0
# 5               £1.60               1540.0          1662.0
# 6               £0.78               1644.0          2769.0
# 7               £1.55               1386.0          1626.0
# 8               £1.19               1686.0          2591.0
# 9                 NaN               1670.0          1938.0
# 10              £1.57               1712.0          2363.0
# 11              £0.26                  NaN          2671.0
# 12              £0.22                  NaN          2624.0
# 13              £0.57                  NaN          2525.0
# 14              £1.09               1670.0          2066.0
# 16              £0.21                  NaN          2983.0
# 19              £2.62               1557.0             NaN
# 20              £1.63               1898.0          3311.0
# 21              £0.15               1832.0          2218.0
# 22              £0.16                  NaN          3542.0
# 23              £0.57                  NaN          1405.0
# 24              £1.52               1779.0          3254.0
# 25              £0.15                  NaN          2584.0
# 26              £1.39               1779.0          2634.0
# 27              £1.40               1772.0          1453.0
# 28              £0.76               1644.0          1877.0
# 29              £1.20               1779.0          2508.0
# 30              £0.75                  NaN          1836.0
# 31              £0.29                  NaN          1776.0
# 32              £2.11               1583.0          1546.0
# 33              £1.60               1779.0          3062.0
# 35              £0.44                  NaN          2003.0
# 36              £3.20               1557.0          1566.0
# 37              £1.16               1538.0          1633.0
# 38              £0.59                  NaN          3124.0
# 39              £1.15               1718.0          1915.0
# 40              £1.45               1779.0          2528.0
# 41              £1.32               1779.0          2535.0
# 42              £0.41               1965.0          1901.0
# 43              £0.45               2137.0          2555.0
#
#     number_takeout_places
# 0                  1048.0
# 1                  1103.0
# 2                  1008.0
# 3                   598.0
# 4                   523.0
# 5                   309.0
# 6                   539.0
# 7                  1729.0
# 8                  2344.0
# 9                   788.0
# 10                  813.0
# 11                  261.0
# 12                 1796.0
# 13                 1435.0
# 14                 1656.0
# 16                  833.0
# 19                  444.0
# 20                  420.0
# 21                  934.0
# 22                  250.0
# 23                  717.0
# 24                 1439.0
# 25                 1183.0
# 26                  588.0
# 27                  659.0
# 28                 5802.0
# 29                 1320.0
# 30                 1257.0
# 31                  346.0
# 32                  988.0
# 33                 1031.0
# 35                 3355.0
# 36                    NaN
# 37                 6417.0
# 38                  492.0
# 39                 2396.0
# 40                  744.0
# 41                 3081.0
# 42                 3206.0
# 43                 1313.0

# %% [markdown]
# # 2
#
# **This dataset contains information on lifestyle measures such as the amount of sunshine, pollution, and happiness levels for 44 major cities around the world.**
#
# * **Drop features with missing values of instance 11 from the dataset.**
#
# **The code contains all imports, loads the dataset, and displays lifestyleClean.info().**

# %%
# Import packages and functions
import pandas as pd

# Load the dataset
lifestyleClean = pd.read_csv('healthy_example.csv')

# Remove features with missing values of 11
lifestyleClean = lifestyleClean.dropna()

lifestyleClean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 30 entries, 0 to 43
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cost_bottled_water     30 non-null     str
#  1   annual_hours_worked    30 non-null     float64
#  2   sunshine_hours         30 non-null     float64
#  3   number_takeout_places  30 non-null     float64
# dtypes: float64(3), str(1)
# memory usage: 1.2 KB

# %% [markdown]
# # 3) **This dataset contains information on lifestyle measures such as the amount of sunshine, pollution, and happiness levels for 44 major cities around the world.**
#
# * **Calculate and print the mean value of sunshine_hours.**
#
# * **Replace the missing values of sunshine_hours in place with the mean of sunshine_hours.**
#
# **The code contains all imports, loads the dataset, and displays healthy['sunshine_hours'].**

# %%
# Import packages and functions
import pandas as pd

# Load the dataset
healthy = pd.read_csv('healthy_example.csv')

# Calculate the mean values of the features
healthyMean = # Your code goes here
print('Mean:', healthyMean['sunshine_hours'], '\n')

# Replace missing values of sunshine_hours in place with the mean of sunshine_hours
# Your code goes here

print(healthy['sunshine_hours'])
